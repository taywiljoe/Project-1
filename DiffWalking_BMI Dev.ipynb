# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv("heart_2020_cleaned.csv")
data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
import pandas as pd

column_data = data['HeartDisease']
print(column_data)
# Out:
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
#          ...
# 319790    Yes
# 319791     No
# 319792     No
# 319793     No
# 319794     No
# Name: HeartDisease, Length: 319795, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt


column_data = data['HeartDisease']

value_counts = column_data.value_counts()

plt.bar(value_counts.index, value_counts.values)

plt.xlabel('Heart Disease')
plt.ylabel('Count')
plt.title('Heart Disease Count')

plt.show()

# %%
column_data = data['DiffWalking']
print(column_data)
# Out:
# 0          No
# 1          No
# 2          No
# 3          No
# 4         Yes
#          ...
# 319790    Yes
# 319791     No
# 319792     No
# 319793     No
# 319794     No
# Name: DiffWalking, Length: 319795, dtype: object

# %%
column_data = data['DiffWalking']

value_counts = column_data.value_counts()

plt.bar(value_counts.index, value_counts.values)

plt.xlabel('DiffWalking')
plt.ylabel('Count')
plt.title('DiffWalking Count')

plt.show()

# %%
column_data = data['SleepTime']
print(column_data)
# Out:
# 0          5.0
# 1          7.0
# 2          8.0
# 3          6.0
# 4          8.0
#           ...
# 319790     6.0
# 319791     5.0
# 319792     6.0
# 319793    12.0
# 319794     8.0
# Name: SleepTime, Length: 319795, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

column_data = data['SleepTime']


sleep_under_7 = (column_data < 7).sum()
sleep_over_7 = (column_data >= 7).sum()


plt.bar(['Sleep < 7 hrs', 'Sleep >= 7 hrs'], [sleep_under_7, sleep_over_7])


plt.xlabel('Sleep Time')
plt.ylabel('Count')
plt.title('Sleep Time Distribution')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


bmi = data['BMI']
heart_disease = data['HeartDisease']


bmi_hd = bmi[heart_disease == 'Yes']

bmi_under_25_hd = (bmi_hd < 25).sum()
bmi_over_25_hd = (bmi_hd >= 25).sum()


labels = ['BMI < 25', 'BMI >= 25']
sizes = [bmi_under_25_hd, bmi_over_25_hd]

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
colors = ['lightcoral', 'lightskyblue']

plt.title('BMI Distribution for People with Heart Disease')


plt.axis('equal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


sleep_time = data['SleepTime']
heart_disease = data['HeartDisease']
bmi = data['BMI']


filtered_data = data[(heart_disease == 'Yes') & (bmi >= 25)]

sleep_under_7_filtered = (filtered_data['SleepTime'] < 7).sum()
sleep_over_7_filtered = (filtered_data['SleepTime'] >= 7).sum()

labels = ['Sleep < 7 hrs', 'Sleep >= 7 hrs']
sizes = [sleep_under_7_filtered, sleep_over_7_filtered]
colors = ['lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Sleep Time Distribution for People with Heart Disease and BMI >= 25')

plt.axis('equal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

bmi = data['BMI']
difficulty_walking = data['DiffWalking']

filtered_data = data[(bmi >= 25) & (difficulty_walking == 'Yes')]

count_with_difficulty_walking = len(filtered_data)
count_without_difficulty_walking = len(data[(bmi >= 25) & (difficulty_walking == 'No')])

labels = ['With DiffWalking', 'Without DiffWalking']
sizes = [count_with_difficulty_walking, count_without_difficulty_walking]
colors = ['lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('BMI >= 25 and DiffWalking')


plt.axis('equal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


bmi = data['BMI']
difficulty_walking = data['DiffWalking']


filtered_data = data[(bmi < 25) & (difficulty_walking == 'Yes')]

count_with_difficulty_walking = len(filtered_data)
count_without_difficulty_walking = len(data[(bmi < 25) & (difficulty_walking == 'No')])

labels = ['With DiffWalking', 'Without DiffWalking']
sizes = [count_with_difficulty_walking, count_without_difficulty_walking]
colors = ['lightcoral', 'lightskyblue']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('BMI < 25 and DiffWalking')

plt.axis('equal')
plt.show()

# %%
sleep_pct = []
sleep_time=[]
for i in range(1,25):
    sleep_time.append(float(i))
    heart_diseased = len(data[(data["SleepTime"]==float(i)) &(data["HeartDisease"]=="Yes")])
    total_shleep = len(data[data["SleepTime"]==float(i)])
    sleep_pct.append(heart_diseased/total_shleep)

plt.scatter(sleep_time,sleep_pct)
plt.show()

# %%
sleep_df = pd.DataFrame({"SleepTime":sleep_time,"Sleep_Percent":sleep_pct})
sleep_df
# Out:
#     SleepTime  Sleep_Percent
# 0         1.0       0.108893
# 1         2.0       0.162437
# 2         3.0       0.174197
# 3         4.0       0.152258
# 4         5.0       0.105817
# 5         6.0       0.081339
# 6         7.0       0.064705
# 7         8.0       0.085633
# 8         9.0       0.105729
# 9        10.0       0.149436
# 10       11.0       0.175904
# 11       12.0       0.188662
# 12       13.0       0.185567
# 13       14.0       0.176955
# 14       15.0       0.126984
# 15       16.0       0.144068
# 16       17.0       0.095238
# 17       18.0       0.205882
# 18       19.0       0.333333
# 19       20.0       0.250000
# 20       21.0       0.000000
# 21       22.0       0.333333
# 22       23.0       0.000000
# 23       24.0       0.200000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called 'data'
# and you want to read the 'HeartDisease' and 'DifficultyWalking' columns
heart_disease = data['HeartDisease']
difficulty_walking = data['DiffWalking']

# Count the occurrences of people with heart disease
heart_disease_count = (heart_disease == 'Yes').sum()

# Count the occurrences of people with difficulty walking
diffwalking_count = (difficulty_walking == 'Yes').sum()

# Count the occurrences of people with no difficulty walking
no_Diffwalking_count = (difficulty_walking == 'No').sum()

# Create the pie chart
labels = ['Heart Disease', 'Difficulty Walking', 'No Difficulty Walking']
sizes = [heart_disease_count, diffwalking_count, no_Diffwalking_count]
colors = ['lightcoral', 'lightskyblue', 'lightgreen']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

# Add title
plt.title('Comparison of Heart Disease and Difficulty Walking')

# Show the plot
plt.axis('equal')
plt.show()

# %%
heart_disease = data['HeartDisease']
difficulty_walking = data['DiffWalking']

people_with_difficulty_walking = data[difficulty_walking == 'Yes']

people_with_difficulty_walking_and_heart_disease = (people_with_difficulty_walking['HeartDisease'] == 'Yes').sum()

people_with_difficulty_walking_no_heart_disease = (people_with_difficulty_walking['HeartDisease'] == 'No').sum()

labels = ['With Heart Disease', 'Without Heart Disease']
sizes = [people_with_difficulty_walking_and_heart_disease, people_with_difficulty_walking_no_heart_disease]
colors = ['lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Heart Disease Among People with Difficulty Walking')

plt.axis('equal')
plt.show()

# %%
heart_disease = data['HeartDisease']
difficulty_walking = data['DiffWalking']

people_without_difficulty_walking = data[difficulty_walking == 'No']

people_without_difficulty_walking_and_heart_disease = (people_without_difficulty_walking['HeartDisease'] == 'Yes').sum()

people_without_difficulty_walking_no_heart_disease = (people_without_difficulty_walking['HeartDisease'] == 'No').sum()

labels = ['With Heart Disease', 'Without Heart Disease']
sizes = [people_without_difficulty_walking_and_heart_disease, people_without_difficulty_walking_no_heart_disease]
colors = ['lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Heart Disease Among People with No Difficulty Walking')

plt.axis('equal')
plt.show()
