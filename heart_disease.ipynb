# %%
import pandas as pd
import matplotlib.pyplot as plt
import import_ipynb 
import Project_1 as prj
# Out:
# importing Jupyter notebook from Project_1.ipynb

# %%
data_1 = pd.read_csv("heart_2020_cleaned.csv")
data_1
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
#%run Project_1.ipynb

# %%
female_data = data_1.loc[data_1["Sex"]=="Female"]

# %%
male_data = data_1.loc[data_1["Sex"]=="Male"]

# %%
male_data.groupby("HeartDisease").aggregate({"HeartDisease":"count"}).plot(kind="pie", y="HeartDisease", autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='HeartDisease'>

# %%
female_data.groupby("HeartDisease").aggregate({"HeartDisease":"count"}).plot(kind="pie", y="HeartDisease", autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='HeartDisease'>

# %%
#total sample of females in each race
female_data.groupby("Race").aggregate({"HeartDisease":"count"})
# Out:
#                                 HeartDisease
# Race
# American Indian/Alaskan Native          2799
# Asian                                   3890
# Black                                  13573
# Hispanic                               14563
# Other                                   5480
# White                                 127500

# %%
heart_disease_females=female_data.loc[female_data["HeartDisease"]=="Yes"].groupby("Race").aggregate({"HeartDisease":"count"})

# %%
heart_disease_females/female_data.groupby("Race").aggregate({"HeartDisease":"count"})
# Out:
#                                 HeartDisease
# Race
# American Indian/Alaskan Native      0.093605
# Asian                               0.022365
# Black                               0.072571
# Hispanic                            0.048273
# Other                               0.070255
# White                               0.069114

# %%
heart_disease_males = male_data.loc[male_data["HeartDisease"]=="Yes"].groupby("Race").aggregate({"HeartDisease":"count"})

# %%
heart_disease_males/male_data.groupby("Race").aggregate({"HeartDisease":"count"})
# Out:
#                                 HeartDisease
# Race
# American Indian/Alaskan Native      0.116521
# Asian                               0.042843
# Black                               0.079436
# Hispanic                            0.057440
# Other                               0.091960
# White                               0.116343

# %%
plt.boxplot((heart_disease_males/male_data.groupby("Race").aggregate({"HeartDisease":"count"}))["HeartDisease"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bca3488a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bca3488f70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bca600ca90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bca3488430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bca3488790>],
#  'means': []}

# %%
prj.yes_heart_disease
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 5               Yes  28.87     Yes              No     No             6.0
# 10              Yes  34.30     Yes              No     No            30.0
# 35              Yes  32.98     Yes              No    Yes            10.0
# 42              Yes  25.06      No              No     No             0.0
# 43              Yes  30.23     Yes              No     No             6.0
# ...             ...    ...     ...             ...    ...             ...
# 319765          Yes  38.45      No              No    Yes            30.0
# 319767          Yes  36.21     Yes              No     No             0.0
# 319781          Yes  37.12     Yes              No     No             0.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
plt.boxplot(prj.yes_heart_disease["BMI"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcaccf64c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bcaccf6a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcaccf61f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bcaccf6fa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcacd022b0>],
#  'means': []}

# %%
plt.boxplot([prj.no_heart_disease["BMI"],prj.yes_heart_disease["BMI"]])
#plt.boxplot(prj.yes_heart_disease["BMI"])
plt.show()

# %%
prj.diabetic
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 2                No  26.58     Yes              No     No            20.0
# 7                No  31.64     Yes              No     No             5.0
# 10              Yes  34.30     Yes              No     No            30.0
# 12               No  28.37     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319767          Yes  36.21     Yes              No     No             0.0
# 319769           No  25.25      No              No     No             0.0
# 319774           No  20.36      No              No     No            30.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
plt.boxplot([prj.no_heart_disease["MentalHealth"],prj.yes_heart_disease["MentalHealth"]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bcacea84c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bcacea8a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bcacea81f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1bcaceb4040>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1bcaceb4310>,
# ...
#  'means': []}

# %%
prj.yes_heart_disease.groupby("Smoking").aggregate({"Smoking":"count"}).plot(kind="pie", y="Smoking", autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='Smoking'>

# %%
female_data.loc[female_data["HeartDisease"]=="Yes"].groupby("Smoking").aggregate({"Smoking":"count"}).plot(kind="pie", y="Smoking", autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='Smoking'>

# %%
male_data.loc[male_data["HeartDisease"]=="Yes"].groupby("Smoking").aggregate({"Smoking":"count"}).plot(kind="pie", y="Smoking", autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='Smoking'>

# %%
#Calculates the pct of American Indians who smoke that have heart disease
len(data_1.loc[(data_1["Race"]=="American Indian/Alaskan Native")&(data_1["Smoking"]=="Yes")&(data_1["HeartDisease"]=="Yes")])/len(data_1.loc[(data_1["Race"]=="American Indian/Alaskan Native")&(data_1["Smoking"]=="Yes")])
# Out:
# 0.13165266106442577

# %%
prj.yes_heart_disease.groupby("AlcoholDrinking").aggregate({"AlcoholDrinking":"count"})
# Out:
#                  AlcoholDrinking
# AlcoholDrinking
# No                         26232
# Yes                         1141

# %%
prj.heart_data.groupby("AlcoholDrinking").aggregate({"AlcoholDrinking":"count"})
# Out:
#                  AlcoholDrinking
# AlcoholDrinking
# No                        298018
# Yes                        21777

# %%
prj.yes_heart_disease.groupby("AlcoholDrinking").aggregate({"AlcoholDrinking":"count"})/prj.heart_data.groupby("AlcoholDrinking").aggregate({"AlcoholDrinking":"count"})
# Out:
#                  AlcoholDrinking
# AlcoholDrinking
# No                      0.088022
# Yes                     0.052395

# %%
prj.heart_data.groupby(["Sex","HeartDisease"]).mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Sex,HeartDisease'>
